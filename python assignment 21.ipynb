# %% [markdown]
# # python assignment 21
#
# Q1. Add the current date to the text file today.txt as a string.
# (Answer)
# from datetime import date
#
# current_date = date.today().strftime("%Y-%m-%d")
#
# with open("today.txt", "a") as file:
#     file.write(current_date)
#     file.write("\n")
#
# Q2. Read the text file today.txt into the string today_string.
# (Answer)
# with open("today.txt", "r") as file:
#     today_string = file.read()
#
# print(today_string)
# This code opens the "today.txt" file in read mode ("r") and uses the read() function to read the entire contents of the file into the today_string variable. Finally, it prints the value of today_string.
# After running this code, the contents of the "today.txt" file will be stored in the today_string variable, and it will be printed to the console.
#
# Q3. Parse the date from today_string.
# (Answer)
# from datetime import datetime
#
# date_format = "%Y-%m-%d"
#
# try:
#     parsed_date = datetime.strptime(today_string.strip(), date_format).date()
#     print(parsed_date)
# except ValueError:
#     print("Error: Unable to parse the date from the string.")
# In this code, we assume that the today_string variable contains a string representing a date in the format "YYYY-MM-DD". The strptime() function from the datetime module is used to parse the string into a datetime object, and then the .date() method is called to extract only the date part.
# The date_format variable specifies the expected format of the date string. Make sure it matches the format of the date in the today_string variable.
#
# Q4. List the files in your current directory.
# (Answer)
# Here's an example:
# import os
#
# directory = "."  # Current directory
#
# file_list = os.listdir(directory)
#
# for file_name in file_list:
#     print(file_name)
#
# Q5.Create a list of all of the files in your parent directory (minimum five files should be available).
# (Answer)
# import os
#
# directory = "../"  # Parent directory
#
# file_list = []
#
# for root, dirs, files in os.walk(directory):
#     for file_name in files:
#         file_list.append(os.path.join(root, file_name))
#
# print(file_list)
#
# Q6. Use multiprocessing to create three separate processes. Make each one wait a random number of
# seconds between one and five, print the current time, and then exit.
# (Answer)
# import multiprocessing
# import random
# import time
# from datetime import datetime
#
# def print_current_time():
#     wait_time = random.randint(1, 5)
#     time.sleep(wait_time)
#     current_time = datetime.now().strftime("%H:%M:%S")
#     print(f"Process ID: {multiprocessing.current_process().name} | Current Time: {current_time}")
#
# if __name__ == '__main__':
#     processes = []
#
#     for _ in range(3):
#         p = multiprocessing.Process(target=print_current_time)
#         processes.append(p)
#         p.start()
#
#     for p in processes:
#         p.join()
# Q7.Create a date object of your day of birth.
# (Answer)
# from datetime import date
#
# birth_year =1999
# birth_month = 04
# birth_day = 22
#
# birth_date = date(birth_year, birth_month, birth_day)
# print(birth_date)
#
# Q8. What day of the week was your day of birth?
# (Answer)
# from datetime import date
#
# birth_year = 1999
# birth_month = 04
# birth_day = 22
#
# birth_date = date(birth_year, birth_month, birth_day)
# day_of_week = birth_date.strftime("%A")
#
# print(day_of_week)
#
# Q9.When will you be (or when were you) 10,000 days old?
# (Answer)
# from datetime import datetime, timedelta
#
#
# birth_year = 1999
# birth_month = 04
# birth_day = 22
#
# birth_date = datetime(birth_year, birth_month, birth_day)
# target_date = birth_date + timedelta(days=10000)
#
# print(target_date.date())
