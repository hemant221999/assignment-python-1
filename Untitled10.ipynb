# %% [markdown]
# # python assignment 3

# %% [raw]
# answer(1)
# Functions are advantageous to have in programs for several reasons:
#
# Reusability: Functions allow you to write a block of code that can be reused multiple times within a program. Instead of writing the same code over and over again, you can simply call the function whenever you need to perform that task.
#
# Modularization: Functions help to break down a large program into smaller, more manageable modules. This makes the program easier to read, understand, and maintain.
#
# Abstraction: Functions can provide a higher level of abstraction, which allows you to hide the details of how a particular task is implemented. This makes it easier to work with complex code, as you can focus on the overall functionality rather than the implementation details.
#
# Testing: Functions can be tested in isolation, which makes it easier to identify and fix bugs. By testing individual functions, you can ensure that each one works correctly before integrating them into the larger program.
#
# Scalability: Functions make it easier to scale a program. As the program grows in size and complexity, functions can be added, removed, or modified without affecting the rest of the program. This makes it easier to maintain and extend the program over time.
#
#
# answer(2)
# The code in a function runs when it is called, not when it is specified.
# When you define a function in a program, you are essentially creating a blueprint for the function. The code inside the function will only run when the function is called from somewhere else in the program.
#
# For example, consider the following Python code:
# def add_numbers(a, b):
#     return a + b
# result = add_numbers(3, 4)
# print(result)
# In this code, the add_numbers function is defined with two parameters a and b. However, the code inside the function (return a + b) will only run when the function is called with specific arguments, as in the line result = add_numbers(3, 4).
# When the function is called with the arguments (3, 4), the code inside the function will execute and return the result 7. This result is then assigned to the variable result and printed to the console with the print function.
#
#
# answer(3)
# In most programming languages, a function is created using a function definition statement. The syntax for defining a function can vary depending on the programming language, but in general, the statement will have the following components:
# The def keyword, which indicates that you are defining a function.
# The name of the function, which should be descriptive of what the function does.
# A set of parentheses, which may or may not contain parameters or arguments that the function accepts.
# A colon, which indicates the beginning of the function body.
# The code or statements that make up the body of the function.
#
#
# answer(4)
# A function is a named block of code that performs a specific task when called or invoked. It is a reusable piece of code that can be executed many times in a program.
# A function call, on the other hand, is the actual execution of the function. It is the point in the program where the function is invoked and the code inside the function is executed with the arguments passed to it.
# In other words, a function is a definition of what the code should do when called, while a function call is the actual execution of that code with specific input values.
#
#
# answer(5)
# In a Python program, there is only one global scope, which is created when the program starts running. This global scope is accessible from anywhere in the program, and any variables or functions defined in the global scope can be accessed from any part of the program.
# On the other hand, local scopes are created whenever a function is called. Each function call creates its own local scope, which is separate from the global scope. Any variables or functions defined within a local scope are only accessible within that scope and are destroyed when the function call is complete.
# It is important to note that local scopes can also be nested. This means that a function can be defined within another function, creating a new local scope within the outer function's local scope. In this case, the inner function can access variables from the outer function's scope, but not vice versa.
#
#
# answer(6)
# When a function call returns, the local variables defined within that function's local scope are destroyed and their memory is freed. This means that any variables, objects, or data structures created within the function's local scope are no longer accessible once the function returns.
# This is because the local scope is created and destroyed every time the function is called and returned, respectively. The local variables only exist as long as the function is executing, and once the function returns, the local scope and all of its contents are destroyed.
#
#
# answer(7)
# A return value is a value that a function sends back to the code that called it. When a function is called, it executes the code within its body and may return a value to the calling code. This value can be used by the calling code for further processing, assignments, or any other purposes.The return value is specified using the return keyword in the function definition.
#
#
# answer(8)
# If a function does not have a return statement, the return value of a call to that function will be None. None is a built-in Python object that represents the absence of a value.
# Consider the following example:
# def greet(name):
#     print("Hello, " + name + "!")
#
# result = greet("Alice")
# print(result)
# In this code, the greet function takes a parameter name, prints a greeting to the console, but does not return any value. The result variable is then assigned the value of the function call greet("Alice"). Since the greet function does not have a return statement, its return value is None.Therefore, the output of the print(result) statement will be None. This is because result is assigned the return value of the greet function, which is None.It's important to note that even though a function may not explicitly return a value, it may still modify global variables or have side effects that affect the program's state.
#
#
# answer(9)
# In Python, you can make a function variable refer to a global variable using the global keyword.When you use the global keyword before a variable name within a function, it tells Python to use the global variable with that name instead of creating a new local variable. This allows you to modify or access the value of a global variable from within a function.
#
#
# answer(10)
# In Python, None is a built-in constant object that represents the absence of a value or a null value. It is often used as a default return value for functions that do not explicitly return a value.None is of type NoneType, which is a built-in type in Python. This means that it is its own data type, separate from other data types like strings, integers, or lists.
#
#
# answer(11)
# The sentence "import areallyourpetsnamederic" is not a valid Python module or package, so if you were to try to run it as a Python command, it would result in a ModuleNotFoundError.In general, the import statement in Python is used to import modules or packages into your Python script or interactive session. A module is a file containing Python definitions and statements that can be used in other Python code, while a package is a collection of modules that are organized hierarchically in a directory structure.
#
#
# answer(12)
# If you had a bacon() function in a spam module, you would call it using the dot notation after importing spam.
# Here is an example:
# Assume we have a spam module with a bacon() function defined in it:
#     def bacon():
#     print("I am bacon!")
# We can then import the spam module into our main Python script and call the bacon() function using the dot notation:
#     import spam
#     spam.bacon()
# In this example, we import the spam module using the import statement, and then call the bacon() function from the spam module using the dot notation (spam.bacon()). The output of this code will be "I am bacon!", since that is the message printed by the bacon() function when it is called.By using the dot notation to access the bacon() function, we can call it as a method of the spam module object that we imported into our script.
#
#
# answer(13)
# There are several techniques that you can use to save a program from crashing if it encounters an error in Python:
# 1)Use a try-except block: You can use a try-except block to catch exceptions and handle them gracefully in your code. The try block contains the code that may raise an exception, while the except block contains the code that will be executed if an exception is raised. By using try-except block, your program can continue to run even if an error occurs.
# 2)Use conditional statements: You can use conditional statements such as if and else to check for conditions that may cause errors in your program, and handle them accordingly.
# 3)Use assertions: You can use assertions to check for conditions that must be true in your program, and raise an exception if they are not. This can help you catch errors early in your code and handle them before they cause more serious problems.
#
# answer(14)
# The try and except clauses are used together in Python to handle exceptions or errors that might occur during the execution of a program.
# The purpose of the try clause is to define a block of code where an error might occur. It allows you to test a piece of code for errors without actually crashing your program. If an error occurs within the try block, Python will stop executing that block and move on to the except block.
# The purpose of the except clause is to define a block of code that will be executed if an error occurs within the try block. The except clause specifies the type of error that should be caught, and the code that should be executed when that error occurs.
